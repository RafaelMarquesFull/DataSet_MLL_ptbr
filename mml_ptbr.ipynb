# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaelMarquesFull/DataSet_MLL_ptbr/blob/main/mml_ptbr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/coqui-ai/TTS.git
# Out:
# Cloning into 'TTS'...
# remote: Enumerating objects: 32844, done.
# remote: Total 32844 (delta 0), reused 0 (delta 0), pack-reused 32844
# Receiving objects: 100% (32844/32844), 166.21 MiB | 15.93 MiB/s, done.
# Resolving deltas: 100% (23820/23820), done.

# %%
# %cd TTS
# !pip install -e .[all,dev,notebooks]

# %%
# %cd /content/TTS/recipes/vctk/yourtts/

# !python train_yourtts.py
# Out:
# /content/TTS/recipes/vctk/yourtts
# RuntimeError: module was compiled against NumPy C-API version 0x10 (NumPy 1.23) but the running NumPy has C-API version 0xf. Check the section C-API incompatibility at the Troubleshooting ImportError section at https://numpy.org/devdocs/user/troubleshooting-importerror.html#c-api-incompatibility for indications on how to solve this problem.
# >>> Downloading VCTK dataset:
# 100% 10.9G/10.9G [1:35:25<00:00, 2.05MB/s]
#  > Extracting archive file...
# Resampling the audio files...
# Found 88328 files...
# 100% 88328/88328 [23:26<00:00, 62.79it/s]
# Done !
# >>> Computing the speaker embeddings for the vctk dataset
#  [!] wav files don't exist - /content/TTS/recipes/vctk/yourtts/VCTK/wav48_silence_trimmed/p362/p362_241_mic1.flac
#  [!] wav files don't exist - /content/TTS/recipes/vctk/yourtts/VCTK/wav48_silence_trimmed/p362/p362_332_mic1.flac
# ...
